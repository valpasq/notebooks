# %% [markdown]
# # Notebook for work on clustering

# %%
import numpy as np
import numpy.ma as ma
import rasterio
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
plt.style.use('ggplot')

#from matplotlib.widgets import Slider, Button, RadioButtons
#import seaborn as sns
#import pandas as pd

import sklearn
from sklearn import cluster
from sklearn import preprocessing
from sklearn import decomposition

# %% [markdown]
# ### Read in Brightness, Greenness and Wetness harmonic images

# %%
with rasterio.open('harm_B.gtif') as harm_B:
     Bright = harm_B.read()  
print(Bright.shape) 

_shp = Bright.shape

Brightness  = np.reshape(Bright, (_shp[0], _shp[1] * _shp[2])).T
Brightness = np.ma.masked_equal(Brightness,-9999)
Brightness_masked = np.ma.compress_rows(Brightness)
print(Brightness.shape)
print(Brightness_masked.shape)
# Out:
# (6, 216, 336)
# (72576, 6)
# (71151, 6)

# %%
with rasterio.open('harm_G.gtif') as harm_G:
    Green = harm_G.read()  
print(Green.shape)

_shp = Green.shape

Greenness  = np.reshape(Green, (_shp[0], _shp[1] * _shp[2])).T
Greenness = np.ma.masked_equal(Greenness,-9999)
Greenness_masked = np.ma.compress_rows(Greenness)
print(Greenness.shape)
print(Greenness_masked.shape)
# Out:
# (6, 216, 336)
# (72576, 6)
# (71151, 6)

# %%
with rasterio.open('harm_W.gtif') as harm_W:
    Wet = harm_W.read()  
print(Wet.shape) 

_shp = Wet.shape

Wetness = np.reshape(Wet, (_shp[0], _shp[1] * _shp[2])).T
Wetness = np.ma.masked_equal(Wetness,-9999)
Wetness_masked = np.ma.compress_rows(Wetness)
print(Wetness.shape)
print(Wetness_masked.shape)
# Out:
# (6, 216, 336)
# (72576, 6)
# (71151, 6)

# %% [markdown]
# ## Figure 1. Distribution of temporal variables

# %%
# %matplotlib nbagg

# Use masked datasets for histograms

fig1 = plt.figure(figsize=(15,20))

plt.subplot2grid((6,3),(0,0))
plt.hist(Brightness_masked[:,0],bins=20)
plt.title('Intercept - Brightness')

plt.subplot2grid((6,3),(0,1))
plt.hist(Greenness_masked[:,0],bins=20)
plt.title('Intercept - Greenness')

plt.subplot2grid((6,3),(0,2))
plt.hist(Wetness_masked[:,0],bins=20)
plt.title('Intercept - Wetness')

plt.subplot2grid((6,3),(1,0))
plt.hist(Brightness_masked[:,1],bins=100)
plt.title('Slope - Brightness')

plt.subplot2grid((6,3),(1,1))
plt.hist(Greenness_masked[:,1],bins=100)
plt.title('Slope - Greenness')

plt.subplot2grid((6,3),(1,2))
plt.hist(Wetness_masked[:,1],bins=100)
plt.title('Slope - Wetness')

plt.subplot2grid((6,3),(2,0))
plt.hist(Brightness_masked[:,2],bins=20)
plt.title('Annual Harmonic - Brightness')

plt.subplot2grid((6,3),(2,1))
plt.hist(Greenness_masked[:,2],bins=20)
plt.title('Annual Harmonic - Greenness')

plt.subplot2grid((6,3),(2,2))
plt.hist(Wetness_masked[:,2],bins=20)
plt.title('Annual Harmonic - Wetness')

plt.subplot2grid((6,3),(3,0))
plt.hist(Brightness_masked[:,3],bins=20)
plt.title('6 month Harmonic - Brightness')

plt.subplot2grid((6,3),(3,1))
plt.hist(Greenness_masked[:,3],bins=20)
plt.title('6 month Harmonic - Greenness')

plt.subplot2grid((6,3),(3,2))
plt.hist(Wetness_masked[:,3],bins=20)
plt.title('6 month Harmonic - Wetness')

plt.subplot2grid((6,3),(4,0))
plt.hist(Brightness_masked[:,4],bins=20)
plt.title('4 month Harmonic - Brightness')

plt.subplot2grid((6,3),(4,1))
plt.hist(Greenness_masked[:,4],bins=20)
plt.title('4 month Harmonic - Greenness')

plt.subplot2grid((6,3),(4,2))
plt.hist(Wetness_masked[:,4],bins=20)
plt.title('4 month Harmonic - Wetness')

plt.subplot2grid((6,3),(5,0))
plt.hist(Brightness_masked[:,4],bins=20)
plt.title('RMSE - Brightness')

plt.subplot2grid((6,3),(5,1))
plt.hist(Greenness_masked[:,5],bins=20)
plt.title('RMSE - Greenness')

plt.subplot2grid((6,3),(5,2))
plt.hist(Wetness_masked[:,5],bins=20)
plt.title('RMSE - Wetness')

fig1.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Read in classification data (labels)

# %%
classes = 7 # need to change this depending on labels imported below

#with rasterio.open('./lu05_labelsTIF.tif') as classification: # 40 classes
with rasterio.open('./LGV_7class1.tif') as classification: # 7 classes
#with rasterio.open('nlcd_reclassTIF.tif') as classification: # 12 classes
    Labels = classification.read()  
print(Labels.shape)
  
_shp = Labels.shape

Labels = np.reshape(Labels, (_shp[0], _shp[1] * _shp[2])).T   
print(Labels.shape)

# ned to apply NoData mask to labels data so shape matches masked BGW data
Labels_m = np.ma.masked_where(np.ma.getmask(Brightness[:,0:1]), Labels)
Labels_masked = np.ma.compress_rows(Labels_m)
print(Labels_masked.shape)
# Out:
# (1, 216, 336)
# (72576, 1)
# (71151, 1)

# %%
print(Labels[500:510,].T)
# Out:
# [[3 3 3 3 3 3 3 3 3 3]]

# %% [markdown]
# ### Create discrete color map

# %%
def cmap_discretize(cmap, N):
    """Return a discrete colormap from the continuous colormap cmap.
    
        cmap: colormap instance, eg. cm.jet. 
        N: number of colors.
    
    Example
        x = resize(arange(100), (5,100))
        djet = cmap_discretize(cm.jet, 5)
        imshow(x, cmap=djet)
    """

    if type(cmap) == str:
        cmap = get_cmap(cmap)
    colors_i = np.concatenate((np.linspace(0, 1., N), (0.,0.,0.,0.)))
    colors_rgba = cmap(colors_i)
    indices = np.linspace(0, 1., N+1)
    cdict = {}
    for ki,key in enumerate(('red','green','blue')):
        cdict[key] = [ (indices[i], colors_rgba[i-1,ki], colors_rgba[i,ki]) for i in xrange(N+1) ]
    # Return colormap object.
    return matplotlib.colors.LinearSegmentedColormap(cmap.name + "_%d"%N, cdict, 1024)

# %%
# Create custom colormap - categorical classes
binmap=cmap_discretize(cm.nipy_spectral,classes)

# %% [markdown]
# ### Select band to plot

# %%
# Band to plot
band=0

# 0=intercept, 1=slope, 2=12mon amp, 3=6mon amp, 4=4mon amp, 5=RMSE

# %% [markdown]
# ## Figure 2. Plot labeled data in 2D TC space

# %%
# %matplotlib nbagg

fig2 = plt.figure(figsize=(15,10))

plt.subplot2grid((2,2),(0,0))
plt.scatter(Brightness[:,band],Greenness[:,band],c=Labels,cmap=binmap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Greenness')
plt.colorbar()

plt.subplot2grid((2,2),(0,1))
plt.scatter(Brightness[:,band],Wetness[:,band],c=Labels,cmap=binmap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Wetness')
plt.colorbar()

plt.subplot2grid((2,2),(1,0))
plt.scatter(Wetness[:,band],Greenness[:,band],c=Labels,cmap=binmap,lw=0);
plt.xlabel('Wetness')
plt.ylabel('Greenness')
plt.colorbar()

fig2.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Figure 3. Plot labeled data in 3D TC space

# %%
# %matplotlib nbagg

fig3 = plt.figure(figsize=(12,10))
ax = fig3.add_subplot(111, projection='3d')

plot3d = ax.scatter(Brightness[:,band],Greenness[:,band],Wetness[:,band],c=Labels,cmap=binmap,lw=0)

plt.title('TC plot')
ax.set_xlabel('Brightness')
ax.set_ylabel('Greenness')
ax.set_zlabel('Wetness')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#axcolor = 'lightgoldenrodyellow'
#axbands = plt.axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)

#sbands = Slider(axbands, 'Bands', 0, 5, valinit=0)

#def update(val):
#    band = sbands.val
#    scatterBG.set_ydata(Bright_arr[band,:,:],Green_arr[band,:,:])
#    fig.canvas.draw_idle()
#sbands.on_changed(update)

# %% [markdown]
# ### Normalize data

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(Brightness_masked)
Brightness_norm = scaler.transform(Brightness_masked)

scaler.fit(Greenness_masked)
Greenness_norm = scaler.transform(Greenness_masked)

scaler.fit(Wetness_masked)
Wetness_norm = scaler.transform(Wetness_masked)

# %%
print(Brightness_norm)
# Out:
# [[ 0.2924301   0.55476993  0.17711268  0.03308769  0.06194678  0.19570065]
#  [ 0.28983477  0.56367612  0.17244625  0.09248263  0.09656033  0.28522635]
#  [ 0.34657261  0.55017185  0.11842923  0.          0.          0.24981377]
#  ...,
#  [ 0.45178536  0.55542558  0.21059862  0.02142328  0.          0.21181676]
#  [ 0.35902765  0.55510598  0.09146227  0.04438849  0.00793739  0.14653519]
#  [ 0.35709015  0.55387574  0.08798341  0.03688503  0.          0.18862098]]

# %%
print(Greenness_norm)
# Out:
# [[ 0.13457634  0.43675187  0.06669696  0.03444508  0.          0.04260179]
#  [ 0.13496752  0.43675187  0.09007033  0.03880421  0.          0.0534649 ]
#  [ 0.1615026   0.43675187  0.13320675  0.02808057  0.01387798  0.06046183]
#  ...,
#  [ 0.51205856  0.43675187  0.27587795  0.02553582  0.08087951  0.15356812]
#  [ 0.5094583   0.43939316  0.43653339  0.10545391  0.12209173  0.13042933]
#  [ 0.60516047  0.44066194  0.54883385  0.05706548  0.14172208  0.17616074]]

# %%
print(Wetness_norm)
# Out:
# [[ 0.71582258  0.47175571  0.09187122  0.          0.          0.13159963]
#  [ 0.70062578  0.45579964  0.0878608   0.          0.          0.1356639 ]
#  [ 0.63633442  0.4732857   0.05964506  0.0129142   0.03017471  0.18744704]
#  ...,
#  [ 0.44158268  0.4732857   0.2906619   0.05689934  0.17661361  0.31038642]
#  [ 0.56827635  0.47452015  0.49049202  0.08243624  0.22097173  0.22205889]
#  [ 0.63650715  0.4778882   0.53349173  0.          0.23558529  0.21965548]]

# %% [markdown]
# ### Create array of temporal data for B+G+W

# %%
BGW_norm = np.hstack([Brightness_norm, Greenness_norm, Wetness_norm])
print(BGW_norm.shape)
# Out:
# (71151, 18)

# %% [markdown]
# ### K-means Clustering - TC variables (spectral clustering)

# %%
k = 7
kmeans = sklearn.cluster.KMeans(n_clusters=k)
kmeans.fit(BGW_norm)

klabels = kmeans.labels_
kcentroids = kmeans.cluster_centers_

# %%
# Create custom colormap - categorical classes
kmap=cmap_discretize(cm.nipy_spectral,k)

# %%
#k = 7
#spectral = sklearn.cluster.SpectralClustering(n_clusters=k)
#spectral.fit(BGW_norm)

#slabels = spectral.labels_

# %% [markdown]
# ## Figure 4. K-means clusters in 2D TC space

# %%
# %matplotlib nbagg

band=0

fig5 = plt.figure(figsize=(15,8))

plt.subplot2grid((2,3),(0,0))
plt.scatter(Brightness_masked[:,band],Greenness_masked[:,band],c=klabels,cmap=kmap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Greenness')
plt.colorbar()

plt.subplot2grid((2,3),(0,1))
plt.scatter(Brightness_masked[:,band],Wetness_masked[:,band],c=klabels,cmap=kmap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Wetness')
plt.colorbar()

plt.subplot2grid((2,3),(0,2))
plt.scatter(Wetness_masked[:,band],Greenness_masked[:,band],c=klabels,cmap=kmap,lw=0);
plt.xlabel('Wetness')
plt.ylabel('Greenness')
plt.colorbar()

plt.subplot2grid((2,3),(1,0))
plt.scatter(Brightness[:,band],Greenness[:,band],c=Labels,cmap=binmap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Greenness')
plt.colorbar()

plt.subplot2grid((2,3),(1,1))
plt.scatter(Brightness[:,band],Wetness[:,band],c=Labels,cmap=binmap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Wetness')
plt.colorbar()

plt.subplot2grid((2,3),(1,2))
plt.scatter(Wetness[:,band],Greenness[:,band],c=Labels,cmap=binmap,lw=0);
plt.xlabel('Wetness')
plt.ylabel('Greenness')
plt.colorbar()

fig5.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Figure 5. K-means clusters in 3D TC space

# %%
# %matplotlib nbagg

fig3 = plt.figure(figsize=(12,10))
ax = fig3.add_subplot(111, projection='3d')

plot3d = ax.scatter(Brightness[:,band],Greenness[:,band],Wetness[:,band],c=klabels,cmap=kmap ,lw=0)

plt.title('TC plot')
ax.set_xlabel('Brightness')
ax.set_ylabel('Greenness')
ax.set_zlabel('Wetness')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Run PCA on temporal dimension - first on B/G/W separately, then all together

# %%
pca = decomposition.PCA(n_components=3, copy=True)

# %%
pca.fit(Brightness_norm)

print("Variance explained:")
print(pca.explained_variance_ratio_) 
print("PCA components:")
print(pca.components_)
# Out:
# Variance explained:
# [ 0.38750512  0.2822982   0.15515067]
# PCA components:
# [[ 0.20223543  0.00252241 -0.94154996 -0.14558807 -0.22428994  0.03281308]
#  [-0.16335656  0.01546803  0.1472645  -0.79177529 -0.32029104 -0.4710564 ]
#  [ 0.88175112 -0.010162    0.1894078  -0.33025014  0.23581572  0.14785968]]

# %%
pca.fit(Greenness_norm)

print("Variance explained:")
print(pca.explained_variance_ratio_) 
print("PCA components:")
print(pca.components_)
# Out:
# Variance explained:
# [ 0.63881633  0.18492569  0.10061637]
# PCA components:
# [[ 0.26586664 -0.00691873  0.83938468  0.37564424  0.24377957  0.15544659]
#  [-0.86530298 -0.02305023  0.16984752  0.39379114 -0.09540817 -0.24020189]
#  [ 0.2182287   0.01293689 -0.45820051  0.81663364 -0.08481374  0.26110792]]

# %%
pca.fit(Wetness_norm)

print("Variance explained:")
print(pca.explained_variance_ratio_) 
print("PCA components:")
print(pca.components_)
# Out:
# Variance explained:
# [ 0.57993982  0.19972039  0.11424575]
# PCA components:
# [[ 0.51742303 -0.00461513 -0.64866555 -0.15163225 -0.40153262 -0.3567414 ]
#  [-0.47983092  0.01804319 -0.50887752 -0.25557369 -0.24965292  0.61873794]
#  [ 0.05780125 -0.00351346 -0.40610003  0.85882634  0.25609288  0.16900653]]

# %%
BGW_trans = pca.fit_transform(BGW_norm)

print("Variance explained:")
print(pca.explained_variance_ratio_) 
print("PCA components:")

Eigen_BGW = pca.components_
print(Eigen_BGW.T)
print(Eigen_BGW.shape)

print(BGW_trans.shape)
print(BGW_trans)
# Out:
# Variance explained:
# [ 0.37841079  0.21147956  0.11308751]
# PCA components:
# [[ 0.1113363  -0.3736667  -0.0197179 ]
#  [-0.00152951  0.00396824  0.01076526]
#  [ 0.27179968  0.41832522  0.03697773]
#  [ 0.07629356  0.06838754 -0.61750305]
#  [ 0.13217629  0.04260701 -0.18945527]
#  [ 0.01204291 -0.11810508 -0.38220501]
#  [ 0.23188475 -0.25636813  0.26855034]
#  [-0.0042817  -0.01239396 -0.00390217]
#  [ 0.68893248  0.25194204  0.16230145]
#  [ 0.30239874  0.22172453 -0.39672223]
#  [ 0.21521433 -0.0409661   0.07961725]
#  [ 0.14653949 -0.15745766 -0.19514605]
#  [-0.15292352  0.44300643  0.14991602]
#  [-0.00317042 -0.01081908 -0.00290697]
#  [ 0.32191703 -0.29384524  0.17284717]
#  [ 0.16036975  0.0346975  -0.08823489]
#  [ 0.20631661 -0.20807649  0.1354094 ]
#  [ 0.08559658 -0.3643052  -0.23680773]]
# (3, 18)
# (71151, 3)
# [[ -4.93273586e-01   8.03830475e-03  -8.98694098e-02]
#  [ -4.64125127e-01   2.37044660e-04  -1.71184942e-01]
# ...

# %% [markdown]
# ### K-means clustering - temporal PCA (spectral-temporal clustering)

# %%
k = 7
kmeans = sklearn.cluster.KMeans(n_clusters=k)
kmeans.fit(BGW_trans)

klabels = kmeans.labels_
kcentroids = kmeans.cluster_centers_

# %% [markdown]
# ## Figure 6. K-means clusters in 2D Temporal PCA space

# %%
# %matplotlib nbagg

fig6 = plt.figure(figsize=(15,8))

plt.subplot2grid((2,3),(0,0))
plt.scatter(BGW_trans[:,0], BGW_trans[:,1], c=klabels, cmap=kmap, lw=0)
plt.xlabel('Temporal PC 1')
plt.ylabel('Temporal PC 2')
plt.colorbar()

plt.subplot2grid((2,3),(0,1))
plt.scatter(BGW_trans[:,1], BGW_trans[:,2], c=klabels, cmap=kmap, lw=0)
plt.xlabel('Temporal PC 2')
plt.ylabel('Temporal PC 3')
plt.colorbar()

plt.subplot2grid((2,3),(0,2))
plt.scatter(BGW_trans[:,0], BGW_trans[:,2], c=klabels, cmap=binmap, lw=0)
plt.xlabel('Temporal PC 1')
plt.ylabel('Temporal PC 3')
plt.colorbar()


plt.subplot2grid((2,3),(1,0))
plt.scatter(BGW_trans[:,0], BGW_trans[:,1], c=Labels_masked, cmap=binmap, lw=0)
plt.xlabel('Temporal PC 1')
plt.ylabel('Temporal PC 2')
plt.colorbar()

plt.subplot2grid((2,3),(1,1))
plt.scatter(BGW_trans[:,1], BGW_trans[:,2], c=Labels_masked, cmap=binmap, lw=0)
plt.xlabel('Temporal PC 2')
plt.ylabel('Temporal PC 3')
plt.colorbar()

plt.subplot2grid((2,3),(1,2))
plt.scatter(BGW_trans[:,0], BGW_trans[:,2], c=Labels_masked, cmap=binmap, lw=0)
plt.xlabel('Temporal PC 1')
plt.ylabel('Temporal PC 3')
plt.colorbar()

plt.show()
fig6.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib nbagg

fig7 = plt.figure(figsize=(12,10))
ax = fig7.add_subplot(111, projection='3d')

plot3d = ax.scatter(BGW_trans[:,0],BGW_trans[:,1],BGW_trans[:,2],c=klabels,cmap=kmap ,lw=0)

plt.title('K-means clusters - spectral-temporal')
ax.set_xlabel('Temporal PC 1')
ax.set_ylabel('Temporal PC 2')
ax.set_zlabel('Temporal PC 3')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib nbagg

fig8 = plt.figure(figsize=(12,10))
ax = fig8.add_subplot(111, projection='3d')

plot3d = ax.scatter(BGW_trans[:,0],BGW_trans[:,1],BGW_trans[:,2],c=Labels_masked,cmap=kmap ,lw=0)

plt.title('Labeled data - spectral-temporal clusters')
ax.set_xlabel('Temporal PC 1')
ax.set_ylabel('Temporal PC 2')
ax.set_zlabel('Temporal PC 3')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Forest data only

# %%
#with rasterio.open('./NLCD_forestD1.tif') as forest_classification:
#with rasterio.open('./BM_mgmtunits1.tif') as forest_classification:
with rasterio.open('./forest_recl1.tif') as forest_classification:
    Forest = forest_classification.read()  
print(Forest.shape)
  
_shp = Forest.shape
Forest = np.reshape(Forest, (_shp[0], _shp[1] * _shp[2])).T   
print(Forest.shape)

Forest_m = np.ma.masked_equal(Forest, 0)
#print(Forest_m.shape)

#Forest_masked = np.ma.compress_rows(Forest_m)
#print(Forest_masked.shape)
# Out:
# (1, 216, 336)
# (72576, 1)

# %%
f=8
formap=cmap_discretize(cm.nipy_spectral,f)

# %%
# %matplotlib nbagg

band=2

fig7 = plt.figure(figsize=(15,5))

plt.subplot2grid((1,3),(0,0))
plt.scatter(Brightness[:,band],Greenness[:,band],c=Forest_m,cmap=formap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Greenness')
plt.colorbar()

plt.subplot2grid((1,3),(0,1))
plt.scatter(Brightness[:,band],Wetness[:,band],c=Forest_m,cmap=formap,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Wetness')
plt.colorbar()

plt.subplot2grid((1,3),(0,2))
plt.scatter(Wetness[:,band],Greenness[:,band],c=Forest_m,cmap=formap,lw=0);
plt.xlabel('Wetness')
plt.ylabel('Greenness')
plt.colorbar()

fig7.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
Brightness_fm = np.ma.masked_where(np.ma.getmask(Forest_m), Brightness[:,:])
Brightness_fm = np.ma.compress_rows(Brightness_fm)
print(Brightness_fm.shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-ce6e2b0aef86> in <module>()
# ----> 1 Brightness_fm = np.ma.masked_where(np.ma.getmask(Forest_m), Brightness[:,:])
#       2 Brightness_fm = np.ma.compress_rows(Brightness_fm)
#       3 print(Brightness_fm.shape)
#
# /project/earth/packages/Python-2.7.5/lib/python2.7/site-packages/numpy/ma/core.pyc in masked_where(condition, a, copy)
#    1809     if cshape and cshape != ashape:
#    1810         raise IndexError("Inconsistant shape between the condition and the input"
# -> 1811                          " (got %s and %s)" % (cshape, ashape))
#    1812     if hasattr(a, '_mask'):
#    1813         cond = mask_or(cond, a._mask)
#
# IndexError: Inconsistant shape between the condition and the input (got (72576, 1) and (72576, 6))

# %% [markdown]
# ##Oak/White Pine comparison - Broadmoor

# %%
with rasterio.open('./GH_Oak1.tif') as oak_classification:
    Oak = oak_classification.read()  
print(Oak.shape)
  
_shp = Oak.shape
Oak = np.reshape(Oak, (_shp[0], _shp[1] * _shp[2])).T   
print(Oak.shape)

Oak_m = np.ma.masked_equal(Oak, 0)
# Out:
# (1, 216, 336)
# (72576, 1)

# %%
with rasterio.open('./WpPlanted1.tif') as wp_classification:
    WP = wp_classification.read()  
print(WP.shape)
  
_shp = WP.shape
WP = np.reshape(WP, (_shp[0], _shp[1] * _shp[2])).T   
print(WP.shape)

WP_m = np.ma.masked_equal(WP, 0)
# Out:
# (1, 216, 336)
# (72576, 1)

# %%
with rasterio.open('./MixedWpOak1.tif') as mixed_classification:
    Mixed = mixed_classification.read()  
print(Mixed.shape)
  
_shp = Mixed.shape
Mixed = np.reshape(Mixed, (_shp[0], _shp[1] * _shp[2])).T   
print(Mixed.shape)

Mixed_m = np.ma.masked_equal(Mixed, 0)
# Out:
# (1, 216, 336)
# (72576, 1)

# %%
# %matplotlib nbagg

fig8 = plt.figure(figsize=(15,8))

band=5

plt.subplot2grid((2,3),(0,0))
plt.hold(True)
plt.scatter(Brightness[:,band],Greenness[:,band],c=Oak_m,cmap=cm.autumn,lw=0);
plt.scatter(Brightness[:,band],Greenness[:,band],c=WP_m,cmap=cm.summer,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Greenness')

plt.subplot2grid((2,3),(0,1))
plt.scatter(Brightness[:,band],Wetness[:,band],c=Oak_m,cmap=cm.autumn,lw=0);
plt.scatter(Brightness[:,band],Wetness[:,band],c=WP_m,cmap=cm.summer,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Wetness')

plt.subplot2grid((2,3),(0,2))
plt.scatter(Wetness[:,band],Greenness[:,band],c=Oak_m,cmap=cm.autumn,lw=0);
plt.scatter(Wetness[:,band],Greenness[:,band],c=WP_m,cmap=cm.summer,lw=0);
plt.xlabel('Wetness')
plt.ylabel('Greenness')

plt.subplot2grid((2,3),(1,0))
plt.scatter(Brightness[:,band],Greenness[:,band],c=Mixed_m,cmap=cm.Accent,lw=0);
plt.scatter(Brightness[:,band],Greenness[:,band],c=Oak_m,cmap=cm.autumn,lw=0);
plt.scatter(Brightness[:,band],Greenness[:,band],c=WP_m,cmap=cm.summer,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Greenness')

plt.subplot2grid((2,3),(1,1))
plt.scatter(Brightness[:,band],Wetness[:,band],c=Mixed_m,cmap=cm.Accent,lw=0);
plt.scatter(Brightness[:,band],Wetness[:,band],c=Oak_m,cmap=cm.autumn,lw=0);
plt.scatter(Brightness[:,band],Wetness[:,band],c=WP_m,cmap=cm.summer,lw=0);
plt.xlabel('Brightness')
plt.ylabel('Wetness')

plt.subplot2grid((2,3),(1,2))
plt.scatter(Wetness[:,band],Greenness[:,band],c=Mixed_m,cmap=cm.Accent,lw=0);
plt.scatter(Wetness[:,band],Greenness[:,band],c=Oak_m,cmap=cm.autumn,lw=0);
plt.scatter(Wetness[:,band],Greenness[:,band],c=WP_m,cmap=cm.summer,lw=0);
plt.xlabel('Wetness')
plt.ylabel('Greenness')

fig8.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
